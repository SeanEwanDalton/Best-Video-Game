# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanEwanDalton/Data-Analytics_Best_Video_Game_GSheets/blob/main/Data_Analytics_Best_Video_Game_GSheets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Important research on the best video games of all time!

# %% [markdown]
# ##Data Analytics and Visualisations

# %% [markdown]
# Steps completed as follow:
#
# 1.   Sourced the data from [Kaggle](https://www.kaggle.com/datasets/faisaljanjua0555/best-video-games-of-all-time?select=data.csv)
# 2.   Loaded into GSheets
# 3.   Cleaned the [raw data](https://github.com/SeanEwanDalton/Data-Analytics_Best_Video_Game_GSheets/blob/main/raw_data.csv) transforming into [enriched data](https://github.com/SeanEwanDalton/Data-Analytics_Best_Video_Game_GSheets/blob/main/Best_Video_Game_Data_Cleaned.csv) ready for analysis
# 4.   Analysed the enriched data and created a [pivot table](https://github.com/SeanEwanDalton/Data-Analytics_Best_Video_Game_GSheets/blob/main/Aggregated_Data_Pivot_Table.csv) to display results
# 5.   Built the visualisations
#
# ![Screenshot 2023-06-05 at 15.59.28.png](data:image/png;base64,...)
#
# ![Screenshot 2023-06-05 at 15.59.07.png](data:image/png;base64,...)
